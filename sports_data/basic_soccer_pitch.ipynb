# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
fig, ax = plt.subplots()

ax.plot([0, 0], [0, 90], linewidth=2, color='black')      # línea vertical izquierda
ax.plot([0, 120], [0,0], linewidth=2, color='black')      # línea horizontal inferior
ax.plot([120, 120], [0, 90], linewidth=2, color='black')  # línea vertical derecha
ax.plot([0, 120], [90, 90], linewidth=2, color='black')   # línea horizontal superior
ax.plot([60, 60], [0, 90], linewidth=2, color='black')    # línea medio campo

ax.plot([-1, -1], [41.3, 47.6], linewidth=2, color='black')    # portería 1
ax.plot([121, 121], [41.3, 47.6], linewidth=2, color='black')  # portería 2

ax.plot(11, 45, 'k.')     # punto penal
ax.plot(120-11, 45, 'k.') # punto penal 2
ax.plot(60, 45, 'k.')     # punto medio campo

half_moon1 = patches.Wedge((11, 45), 9.15, 310, 50, linewidth=2, edgecolor='k', facecolor='none')    # media luna 1
half_moon2 = patches.Wedge((109, 45), 9.15, 130, 230, linewidth=2, edgecolor='k', facecolor='none')  # media luna 2

ax.add_patch(half_moon1)
ax.add_patch(half_moon2)

box1 = patches.Rectangle((0,24.85), 16.5, 40.3, linewidth=2, edgecolor='k', facecolor='white') # área grande 1
box2 = patches.Rectangle((120-16.5,24.85), 16.5, 40.3, linewidth=2, edgecolor='k', facecolor='white') # área grande 2

box3 = patches.Rectangle((0,35.85), 5.5, 18.3, linewidth=2, edgecolor='k', facecolor='none') # área chica 1
box4 = patches.Rectangle((120-5.5,35.85), 5.5, 18.3, linewidth=2, edgecolor='k', facecolor='none') # área chica 2

ax.add_patch(box1)
ax.add_patch(box2)
ax.add_patch(box3)
ax.add_patch(box4)

circle = patches.Circle((60, 45), 9.15, linewidth=2, edgecolor='k', facecolor='none') # circulo central
ax.add_patch(circle)

corner_ii = patches.Wedge((0, 0), 2, 0, 90, linewidth=2, edgecolor='k', facecolor='none') # corner inferior izquierdo
corner_id = patches.Wedge((120, 0), 2, 90, 180, linewidth=2, edgecolor='k', facecolor='none') # corner inferior derecho
corner_si = patches.Wedge((0, 90), 2, 270, 0, linewidth=2, edgecolor='k', facecolor='none') # corner superior izquierdo
corner_sd = patches.Wedge((120, 90), 2, 180, 270, linewidth=2, edgecolor='k', facecolor='none') # corner superior derecho

ax.add_patch(corner_ii)
ax.add_patch(corner_id)
ax.add_patch(corner_si)
ax.add_patch(corner_sd)

plt.suptitle("Barcelona vs Real Madrid", fontsize=18)
plt.title("J20 | Temporada 2022 - 2023 | La Liga", fontsize=10)
plt.axis('off')

plt.show()
